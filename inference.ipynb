# %% [markdown]
# ## Tacotron 2 inference code
# Edit the variables **checkpoint_path** and **text** to match yours and run the entire code to generate plots of mel outputs, alignments and audio synthesis from the generated mel-spectrogram using Griffin-Lim.

# %% [markdown]
# #### Import libraries and setup matplotlib

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pylab as plt

import IPython.display as ipd

import sys
sys.path.append('waveglow/')
import numpy as np
import torch

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser
# Out:
# /mnt/shared_ad2_mt1/hbauerec/tacotron2/plotting_utils.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/asyncio/base_events.py", line 442, in run_forever
#     self._run_once()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/asyncio/base_events.py", line 1462, in _run_once
#     handle._run()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/tornado/gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-9a82931866e2>", line 2, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2966, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 315, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/matplotlib/pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use("Agg")

# %%
def plot_data(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='bottom', 
                       interpolation='none')

# %% [markdown]
# #### Setup hparams

# %%
hparams = create_hparams()
hparams.sampling_rate = 22050

# %% [markdown]
# #### Load model from checkpoint

# %%
checkpoint_path = "outdir_pitch/checkpoint_1000"
#checkpoint_path = "pretrained/tacotron2_statedict.pt"
model = load_model(hparams)
model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
_ = model.cuda().eval().half()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-5c2c17f64b8c> in <module>()
#       1 checkpoint_path = "outdir_pitch/checkpoint_1000"
#       2 #checkpoint_path = "pretrained/tacotron2_statedict.pt"
# ----> 3 model = load_model(hparams)
#       4 model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
#       5 _ = model.cuda().eval().half()
#
# /mnt/shared_ad2_mt1/hbauerec/tacotron2/train.py in load_model(hparams)
#      73
#      74 def load_model(hparams):
# ---> 75     model = Tacotron2(hparams).cuda()
#      76     if hparams.fp16_run:
#      77         model.decoder.attention_layer.score_mask_value = finfo('float16').min
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     221                 # `with torch.no_grad():`
#     222                 with torch.no_grad():
# --> 223                     param_applied = fn(param)
#     224                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     225                 if should_use_set_data:
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# RuntimeError: CUDA error: device-side assert triggered

# %% [markdown]
# #### Load WaveGlow for mel2audio synthesis and denoiser

# %%
waveglow_path = 'pretrained/waveglow_256channels_universal_v5.pt'
waveglow = torch.load(waveglow_path)['model']
waveglow.cuda().eval().half()
for k in waveglow.convinv:
    k.float()
denoiser = Denoiser(waveglow)

# %% [markdown]
# #### Prepare text input

# %%
text = "hickery dickery duck the mouse went up the clock"
sequence = np.array(text_to_sequence(text, ['english_cleaners']))[None, :]
sequence = torch.autograd.Variable(
    torch.from_numpy(sequence)).cuda().long()
sequence
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5acd8864b5e1> in <module>()
#       1 text = "hickery dickery duck the mouse went up the clock"
# ----> 2 sequence = np.array(text_to_sequence(text, ['english_cleaners']))[None, :]
#       3 sequence = torch.autograd.Variable(
#       4     torch.from_numpy(sequence)).cuda().long()
#       5 sequence
#
# NameError: name 'np' is not defined

# %%
from audio import audio_to_seq
test_file="/mnt/shared_ad2_mt1/hbauerec/data/LJSpeech-1.1/wavs/LJ045-0096.wav"

sequence = np.array(audio_to_seq(test_file))[None, :48]
sequence = torch.autograd.Variable(
    torch.from_numpy(sequence)).cuda().long()
sequence
# Out:
# tensor([[148,  62, 117, 118, 118, 118,  62, 116, 116,  68,  68,  54,  52,  70,
#           70,  70,  70,  69,  51, 107, 109,  73,  72,  72,  70,   0,   0, 106,
#          125, 124,  57,  76,  78,  79,  79,  75,  58,  76,  75,  74,  83,  83,
#           83,  82,  62, 117, 117,  52]], device='cuda:0')

# %% [markdown]
# #### Decode text input and plot results

# %%
mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
plot_data((mel_outputs.float().data.cpu().numpy()[0],
           mel_outputs_postnet.float().data.cpu().numpy()[0],
           alignments.float().data.cpu().numpy()[0].T))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-2e5552ce83d1> in <module>()
# ----> 1 mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
#       2 plot_data((mel_outputs.float().data.cpu().numpy()[0],
#       3            mel_outputs_postnet.float().data.cpu().numpy()[0],
#       4            alignments.float().data.cpu().numpy()[0].T))
#
# /mnt/shared_ad2_mt1/hbauerec/tacotron2/model.py in inference(self, inputs)
#     517     def inference(self, inputs):
#     518         embedded_inputs = self.embedding(inputs).transpose(1, 2)
# --> 519         encoder_outputs = self.encoder.inference(embedded_inputs)
#     520         mel_outputs, gate_outputs, alignments = self.decoder.inference(
#     521             encoder_outputs)
#
# /mnt/shared_ad2_mt1/hbauerec/tacotron2/model.py in inference(self, x)
#     197
#     198         self.lstm.flatten_parameters()
# --> 199         outputs, _ = self.lstm(x)
#     200
#     201         return outputs
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /home/hbauerec/dev/venv/pytorch1.4/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557         if batch_sizes is None:
#     558             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 559                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     560         else:
#     561             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED

# %% [markdown]
# #### Synthesize audio from spectrogram using WaveGlow

# %%
with torch.no_grad():
    audio = waveglow.infer(mel_outputs_postnet, sigma=0.666)
ipd.Audio(audio[0].data.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### (Optional) Remove WaveGlow bias

# %%
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
ipd.Audio(audio_denoised.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import sys
sys.path.append('waveglow/')
import numpy as np
import torch

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser

# %%
import IPython.display as ipd

import sys
sys.path.append('waveglow/')
import numpy as np
import torch

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser
